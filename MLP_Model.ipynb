# %% [markdown]
# # data preparation for Model

# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df=pd.read_csv('/content/final_dataset.csv')
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.321275  0.729664  0.750033  0.730624  0.735275  0.713529  0.660531
# 1  0.319643  0.793979  0.839747  0.821713  0.814604  0.809805  0.706333
# 2  0.188256  0.622125  0.699215  0.753343  0.721212  0.701727  0.682356
# 3  0.293566  0.673896  0.722096  0.723508  0.682302  0.680533  0.675352
# 4  0.332122  0.783231  0.818937  0.808798  0.784825  0.795725  0.759460
#
#           7         8         9  ...           153           154  \
# 0  0.684966  0.733049  0.753972  ...  4.310903e-06  3.291511e-06
# 1  0.669973  0.723464  0.754674  ...  6.023504e-05  5.953494e-05
# 2  0.662828  0.686486  0.733960  ...  8.579052e-07  9.576654e-07
# 3  0.628977  0.679179  0.707283  ...  6.984504e-06  7.034949e-06
# 4  0.659879  0.697119  0.730823  ...  1.398844e-04  1.446267e-04
#
#             155           156           157           158       159       160  \
# 0  2.148075e-06  2.279739e-06  5.116493e-06  8.190282e-06  0.000007  0.000005
# 1  6.059830e-05  5.958963e-05  5.543482e-05  6.296567e-05  0.000066  0.000062
# 2  7.733596e-07  5.233101e-07  3.592860e-07  9.261693e-07  0.000002  0.000001
# 3  6.654923e-06  6.979548e-06  1.214236e-05  9.640184e-06  0.000011  0.000006
# 4  1.442047e-04  1.332205e-04  1.477816e-04  1.423757e-04  0.000139  0.000142
#
#             161   labels
# 0  4.245834e-07  neutral
# 1  5.589501e-05  neutral
# 2  7.753986e-08  neutral
# 3  4.254087e-07  neutral
# 4  1.284356e-04  neutral
#
# [5 rows x 163 columns]

# %%
df.shape
# Out:
# (36486, 163)

# %%
X = df.iloc[: ,:-1].values
Y = df['labels'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((27364, 162), (27364, 8), (9122, 162), (9122, 8))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((27364, 162), (27364, 8), (9122, 162), (9122, 8))

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((27364, 162, 1), (27364, 8), (9122, 162, 1), (9122, 8))

# %% [markdown]
# # Base Model accurate Model

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=8, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 162, 256)          1536
#
#  max_pooling1d (MaxPooling1  (None, 81, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 81, 256)           327936
#
#  max_pooling1d_1 (MaxPoolin  (None, 41, 256)           0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 41, 128)           163968
#
#  max_pooling1d_2 (MaxPoolin  (None, 21, 128)           0
#  g1D)
#
#  dropout (Dropout)           (None, 21, 128)           0
#
#  conv1d_3 (Conv1D)           (None, 21, 64)            41024
#
#  max_pooling1d_3 (MaxPoolin  (None, 11, 64)            0
#  g1D)
#
#  flatten (Flatten)           (None, 704)               0
#
#  dense (Dense)               (None, 32)                22560
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 557288 (2.13 MB)
# Trainable params: 557288 (2.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 428/428 [==============================] - 16s 13ms/step - loss: 1.7275 - accuracy: 0.3042 - val_loss: 1.4533 - val_accuracy: 0.4236 - lr: 0.0010
# Epoch 2/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.4608 - accuracy: 0.4149 - val_loss: 1.3518 - val_accuracy: 0.4622 - lr: 0.0010
# Epoch 3/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.3682 - accuracy: 0.4540 - val_loss: 1.2432 - val_accuracy: 0.4956 - lr: 0.0010
# Epoch 4/50
# 428/428 [==============================] - 5s 11ms/step - loss: 1.3034 - accuracy: 0.4764 - val_loss: 1.2217 - val_accuracy: 0.5015 - lr: 0.0010
# Epoch 5/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.2630 - accuracy: 0.4927 - val_loss: 1.1876 - val_accuracy: 0.5197 - lr: 0.0010
# Epoch 6/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.2267 - accuracy: 0.5083 - val_loss: 1.2092 - val_accuracy: 0.5103 - lr: 0.0010
# Epoch 7/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.2077 - accuracy: 0.5167 - val_loss: 1.1561 - val_accuracy: 0.5381 - lr: 0.0010
# Epoch 8/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.1837 - accuracy: 0.5268 - val_loss: 1.1604 - val_accuracy: 0.5403 - lr: 0.0010
# Epoch 9/50
# 428/428 [==============================] - 5s 12ms/step - loss: 1.1690 - accuracy: 0.5356 - val_loss: 1.1219 - val_accuracy: 0.5538 - lr: 0.0010
# Epoch 10/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.1505 - accuracy: 0.5411 - val_loss: 1.1318 - val_accuracy: 0.5520 - lr: 0.0010
# Epoch 11/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.1299 - accuracy: 0.5477 - val_loss: 1.1161 - val_accuracy: 0.5492 - lr: 0.0010
# Epoch 12/50
# 428/428 [==============================] - 5s 13ms/step - loss: 1.1170 - accuracy: 0.5574 - val_loss: 1.1452 - val_accuracy: 0.5334 - lr: 0.0010
# Epoch 13/50
# 428/428 [==============================] - 5s 11ms/step - loss: 1.1179 - accuracy: 0.5559 - val_loss: 1.0885 - val_accuracy: 0.5620 - lr: 0.0010
# Epoch 14/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.0896 - accuracy: 0.5638 - val_loss: 1.0852 - val_accuracy: 0.5665 - lr: 0.0010
# Epoch 15/50
# 428/428 [==============================] - 5s 11ms/step - loss: 1.0819 - accuracy: 0.5694 - val_loss: 1.0709 - val_accuracy: 0.5710 - lr: 0.0010
# Epoch 16/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.0648 - accuracy: 0.5775 - val_loss: 1.0922 - val_accuracy: 0.5642 - lr: 0.0010
# Epoch 17/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.0571 - accuracy: 0.5816 - val_loss: 1.0768 - val_accuracy: 0.5651 - lr: 0.0010
# Epoch 18/50
# 428/428 [==============================] - 5s 11ms/step - loss: 1.0517 - accuracy: 0.5809 - val_loss: 1.0638 - val_accuracy: 0.5727 - lr: 0.0010
# Epoch 19/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.0317 - accuracy: 0.5911 - val_loss: 1.0877 - val_accuracy: 0.5624 - lr: 0.0010
# Epoch 20/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.0229 - accuracy: 0.5952 - val_loss: 1.0681 - val_accuracy: 0.5730 - lr: 0.0010
# Epoch 21/50
# 428/428 [==============================] - 5s 12ms/step - loss: 1.0089 - accuracy: 0.5998 - val_loss: 1.0620 - val_accuracy: 0.5790 - lr: 0.0010
# Epoch 22/50
# 428/428 [==============================] - 4s 10ms/step - loss: 1.0055 - accuracy: 0.6051 - val_loss: 1.0477 - val_accuracy: 0.5782 - lr: 0.0010
# Epoch 23/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.9936 - accuracy: 0.6065 - val_loss: 1.0701 - val_accuracy: 0.5745 - lr: 0.0010
# Epoch 24/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.9867 - accuracy: 0.6108 - val_loss: 1.0581 - val_accuracy: 0.5836 - lr: 0.0010
# Epoch 25/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.9716 - accuracy: 0.6155 - val_loss: 1.0710 - val_accuracy: 0.5782 - lr: 0.0010
# Epoch 26/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.9589 - accuracy: 0.6202 - val_loss: 1.0369 - val_accuracy: 0.5904 - lr: 0.0010
# Epoch 27/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.9446 - accuracy: 0.6235 - val_loss: 1.0611 - val_accuracy: 0.5790 - lr: 0.0010
# Epoch 28/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.9447 - accuracy: 0.6253 - val_loss: 1.0342 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 29/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.9324 - accuracy: 0.6321 - val_loss: 1.0357 - val_accuracy: 0.5872 - lr: 0.0010
# Epoch 30/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.9252 - accuracy: 0.6338 - val_loss: 1.0502 - val_accuracy: 0.5932 - lr: 0.0010
# Epoch 31/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.9162 - accuracy: 0.6412 - val_loss: 1.0273 - val_accuracy: 0.5908 - lr: 0.0010
# Epoch 32/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.9062 - accuracy: 0.6454 - val_loss: 1.0285 - val_accuracy: 0.6039 - lr: 0.0010
# Epoch 33/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.8956 - accuracy: 0.6458 - val_loss: 1.0690 - val_accuracy: 0.5919 - lr: 0.0010
# Epoch 34/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.9046 - accuracy: 0.6461 - val_loss: 1.0835 - val_accuracy: 0.5937 - lr: 0.0010
# Epoch 35/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.8812 - accuracy: 0.6513 - val_loss: 1.0552 - val_accuracy: 0.5945 - lr: 0.0010
# Epoch 36/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.8778 - accuracy: 0.6570 - val_loss: 1.0730 - val_accuracy: 0.5873 - lr: 0.0010
# Epoch 37/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.8663 - accuracy: 0.6612 - val_loss: 1.0622 - val_accuracy: 0.5931 - lr: 0.0010
# Epoch 38/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.8655 - accuracy: 0.6626 - val_loss: 1.0543 - val_accuracy: 0.5933 - lr: 0.0010
# Epoch 39/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.8546 - accuracy: 0.6617 - val_loss: 1.0353 - val_accuracy: 0.5999 - lr: 0.0010
# Epoch 40/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.8452 - accuracy: 0.6650 - val_loss: 1.0475 - val_accuracy: 0.5932 - lr: 0.0010
# Epoch 41/50
# 428/428 [==============================] - 5s 12ms/step - loss: 0.8455 - accuracy: 0.6693 - val_loss: 1.0668 - val_accuracy: 0.5947 - lr: 0.0010
# Epoch 42/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.8202 - accuracy: 0.6765 - val_loss: 1.0346 - val_accuracy: 0.6050 - lr: 0.0010
# Epoch 43/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.8178 - accuracy: 0.6801 - val_loss: 1.0371 - val_accuracy: 0.6020 - lr: 0.0010
# Epoch 44/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.8097 - accuracy: 0.6793 - val_loss: 1.0724 - val_accuracy: 0.6051 - lr: 0.0010
# Epoch 45/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.8076 - accuracy: 0.6836 - val_loss: 1.0662 - val_accuracy: 0.6069 - lr: 0.0010
# Epoch 46/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.8008 - accuracy: 0.6858 - val_loss: 1.0903 - val_accuracy: 0.6021 - lr: 0.0010
# Epoch 47/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.7938 - accuracy: 0.6905 - val_loss: 1.0964 - val_accuracy: 0.6048 - lr: 0.0010
# Epoch 48/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.7871 - accuracy: 0.6938 - val_loss: 1.0956 - val_accuracy: 0.5973 - lr: 0.0010
# Epoch 49/50
# 428/428 [==============================] - 4s 10ms/step - loss: 0.7866 - accuracy: 0.6954 - val_loss: 1.0967 - val_accuracy: 0.6040 - lr: 0.0010
# Epoch 50/50
# 428/428 [==============================] - 5s 11ms/step - loss: 0.7640 - accuracy: 0.7017 - val_loss: 1.0750 - val_accuracy: 0.6109 - lr: 0.0010

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 286/286 [==============================] - 1s 4ms/step - loss: 1.0750 - accuracy: 0.6109
# Accuracy of our model on test data :  61.09405755996704 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0              sad       disgust
# 1          disgust       disgust
# 2            angry         angry
# 3          disgust       disgust
# 4              sad          fear
# 5          disgust          fear
# 6             fear         happy
# 7            happy         happy
# 8              sad           sad
# 9          neutral           sad

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.76      0.73      0.74      1438
#         calm       0.59      0.90      0.71       137
#      disgust       0.56      0.47      0.51      1468
#         fear       0.64      0.50      0.56      1424
#        happy       0.57      0.54      0.56      1462
#      neutral       0.61      0.55      0.58      1310
#          sad       0.51      0.78      0.62      1400
#     surprise       0.83      0.84      0.84       483
#
#     accuracy                           0.61      9122
#    macro avg       0.63      0.66      0.64      9122
# weighted avg       0.62      0.61      0.61      9122

# %% [markdown]
# # Model Tuning

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Activation, BatchNormalization

def cnn2(X_train, y_train):
    model = Sequential()

    # First Convolutional Layer
    model.add(Conv1D(256, 8, padding='same', input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Activation('relu'))

    # Second Convolutional Layer
    model.add(Conv1D(256, 8, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=8))

    # Third Convolutional Layer
    model.add(Conv1D(128, 8, padding='same'))
    model.add(Activation('relu'))

    # Fourth Convolutional Layer
    model.add(Conv1D(128, 8, padding='same'))
    model.add(Activation('relu'))

    # Fifth Convolutional Layer
    model.add(Conv1D(128, 8, padding='same'))
    model.add(Activation('relu'))

    # Sixth Convolutional Layer
    model.add(Conv1D(128, 8, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=8))

    # Seventh Convolutional Layer
    model.add(Conv1D(64, 8, padding='same'))
    model.add(Activation('relu'))

    # Eighth Convolutional Layer
    model.add(Conv1D(64, 8, padding='same'))
    model.add(Activation('relu'))

    # Flatten Layer
    model.add(Flatten())

    # Dense Layer
    model.add(Dense(units=8, activation='softmax'))# Number of target classes

    # Compile Model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Assuming your model and data setup is correct
model = cnn2(x_train, y_train)

# Define ReduceLROnPlateau callback
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1)

# Train the model
history = model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 428/428 [==============================] - 12s 20ms/step - loss: 1.5336 - accuracy: 0.3811 - val_loss: 1.4182 - val_accuracy: 0.4319 - lr: 0.0010
# Epoch 2/50
# 428/428 [==============================] - 7s 17ms/step - loss: 1.2733 - accuracy: 0.4957 - val_loss: 1.3000 - val_accuracy: 0.4861 - lr: 0.0010
# Epoch 3/50
# 428/428 [==============================] - 8s 18ms/step - loss: 1.1791 - accuracy: 0.5304 - val_loss: 1.2521 - val_accuracy: 0.4948 - lr: 0.0010
# Epoch 4/50
# 428/428 [==============================] - 7s 17ms/step - loss: 1.1261 - accuracy: 0.5512 - val_loss: 1.2582 - val_accuracy: 0.4824 - lr: 0.0010
# Epoch 5/50
# 428/428 [==============================] - 8s 20ms/step - loss: 1.0841 - accuracy: 0.5706 - val_loss: 1.1304 - val_accuracy: 0.5659 - lr: 0.0010
# Epoch 6/50
# 428/428 [==============================] - 8s 19ms/step - loss: 1.0449 - accuracy: 0.5862 - val_loss: 1.1936 - val_accuracy: 0.5175 - lr: 0.0010
# Epoch 7/50
# 428/428 [==============================] - 7s 17ms/step - loss: 1.0094 - accuracy: 0.5983 - val_loss: 1.0805 - val_accuracy: 0.5787 - lr: 0.0010
# Epoch 8/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.9778 - accuracy: 0.6146 - val_loss: 1.1000 - val_accuracy: 0.5584 - lr: 0.0010
# Epoch 9/50
# 428/428 [==============================] - 9s 21ms/step - loss: 0.9487 - accuracy: 0.6256 - val_loss: 1.0826 - val_accuracy: 0.5714 - lr: 0.0010
# Epoch 10/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.9150 - accuracy: 0.6427 - val_loss: 1.1305 - val_accuracy: 0.5497 - lr: 0.0010
# Epoch 11/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.8858 - accuracy: 0.6528 - val_loss: 1.0368 - val_accuracy: 0.5916 - lr: 0.0010
# Epoch 12/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.8559 - accuracy: 0.6653 - val_loss: 1.0151 - val_accuracy: 0.5954 - lr: 0.0010
# Epoch 13/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.8216 - accuracy: 0.6791 - val_loss: 1.0812 - val_accuracy: 0.5787 - lr: 0.0010
# Epoch 14/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.7846 - accuracy: 0.6943 - val_loss: 1.0004 - val_accuracy: 0.6094 - lr: 0.0010
# Epoch 15/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.7574 - accuracy: 0.7063 - val_loss: 1.0907 - val_accuracy: 0.5872 - lr: 0.0010
# Epoch 16/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.7231 - accuracy: 0.7171 - val_loss: 1.0526 - val_accuracy: 0.5921 - lr: 0.0010
# Epoch 17/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.6931 - accuracy: 0.7330 - val_loss: 0.9493 - val_accuracy: 0.6254 - lr: 0.0010
# Epoch 18/50
# 428/428 [==============================] - 8s 20ms/step - loss: 0.6572 - accuracy: 0.7475 - val_loss: 1.0390 - val_accuracy: 0.6007 - lr: 0.0010
# Epoch 19/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.6406 - accuracy: 0.7535 - val_loss: 0.9786 - val_accuracy: 0.6273 - lr: 0.0010
# Epoch 20/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.6056 - accuracy: 0.7681 - val_loss: 0.9922 - val_accuracy: 0.6218 - lr: 0.0010
# Epoch 21/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.5904 - accuracy: 0.7734 - val_loss: 0.9878 - val_accuracy: 0.6307 - lr: 0.0010
# Epoch 22/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.5612 - accuracy: 0.7868 - val_loss: 0.9078 - val_accuracy: 0.6643 - lr: 0.0010
# Epoch 23/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.5329 - accuracy: 0.7957 - val_loss: 0.9235 - val_accuracy: 0.6614 - lr: 0.0010
# Epoch 24/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.5162 - accuracy: 0.8042 - val_loss: 0.9578 - val_accuracy: 0.6560 - lr: 0.0010
# Epoch 25/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.4942 - accuracy: 0.8123 - val_loss: 0.9652 - val_accuracy: 0.6480 - lr: 0.0010
# Epoch 26/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.4767 - accuracy: 0.8194 - val_loss: 0.9623 - val_accuracy: 0.6501 - lr: 0.0010
# Epoch 27/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.4577 - accuracy: 0.8266 - val_loss: 0.9403 - val_accuracy: 0.6684 - lr: 0.0010
# Epoch 28/50
# 428/428 [==============================] - 8s 20ms/step - loss: 0.4398 - accuracy: 0.8356 - val_loss: 1.0584 - val_accuracy: 0.6342 - lr: 0.0010
# Epoch 29/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.4157 - accuracy: 0.8417 - val_loss: 1.0083 - val_accuracy: 0.6493 - lr: 0.0010
# Epoch 30/50
# 428/428 [==============================] - 8s 20ms/step - loss: 0.4094 - accuracy: 0.8463 - val_loss: 0.9514 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 31/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.3917 - accuracy: 0.8516 - val_loss: 0.9495 - val_accuracy: 0.6758 - lr: 0.0010
# Epoch 32/50
# 428/428 [==============================] - ETA: 0s - loss: 0.3748 - accuracy: 0.8595
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 428/428 [==============================] - 7s 17ms/step - loss: 0.3748 - accuracy: 0.8595 - val_loss: 0.9915 - val_accuracy: 0.6592 - lr: 0.0010
# Epoch 33/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.2725 - accuracy: 0.9000 - val_loss: 0.9664 - val_accuracy: 0.6954 - lr: 1.0000e-04
# Epoch 34/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.2363 - accuracy: 0.9122 - val_loss: 0.9720 - val_accuracy: 0.6998 - lr: 1.0000e-04
# Epoch 35/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.2183 - accuracy: 0.9190 - val_loss: 1.0222 - val_accuracy: 0.6980 - lr: 1.0000e-04
# Epoch 36/50
# 428/428 [==============================] - 8s 20ms/step - loss: 0.2046 - accuracy: 0.9225 - val_loss: 1.0316 - val_accuracy: 0.6996 - lr: 1.0000e-04
# Epoch 37/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.1953 - accuracy: 0.9264 - val_loss: 1.0555 - val_accuracy: 0.7019 - lr: 1.0000e-04
# Epoch 38/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.1876 - accuracy: 0.9296 - val_loss: 1.0801 - val_accuracy: 0.6995 - lr: 1.0000e-04
# Epoch 39/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.1817 - accuracy: 0.9329 - val_loss: 1.0812 - val_accuracy: 0.7003 - lr: 1.0000e-04
# Epoch 40/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.1737 - accuracy: 0.9339 - val_loss: 1.1089 - val_accuracy: 0.7037 - lr: 1.0000e-04
# Epoch 41/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.1661 - accuracy: 0.9374 - val_loss: 1.1347 - val_accuracy: 0.6998 - lr: 1.0000e-04
# Epoch 42/50
# 425/428 [============================>.] - ETA: 0s - loss: 0.1654 - accuracy: 0.9374
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 428/428 [==============================] - 8s 18ms/step - loss: 0.1656 - accuracy: 0.9373 - val_loss: 1.1424 - val_accuracy: 0.7032 - lr: 1.0000e-04
# Epoch 43/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.1494 - accuracy: 0.9451 - val_loss: 1.1459 - val_accuracy: 0.7032 - lr: 1.0000e-05
# Epoch 44/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.1487 - accuracy: 0.9462 - val_loss: 1.1492 - val_accuracy: 0.7050 - lr: 1.0000e-05
# Epoch 45/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.1435 - accuracy: 0.9465 - val_loss: 1.1584 - val_accuracy: 0.7027 - lr: 1.0000e-05
# Epoch 46/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.1433 - accuracy: 0.9468 - val_loss: 1.1595 - val_accuracy: 0.7027 - lr: 1.0000e-05
# Epoch 47/50
# 428/428 [==============================] - 9s 21ms/step - loss: 0.1432 - accuracy: 0.9485 - val_loss: 1.1637 - val_accuracy: 0.7029 - lr: 1.0000e-05
# Epoch 48/50
# 428/428 [==============================] - 8s 19ms/step - loss: 0.1448 - accuracy: 0.9450 - val_loss: 1.1727 - val_accuracy: 0.7027 - lr: 1.0000e-05
# Epoch 49/50
# 428/428 [==============================] - 7s 17ms/step - loss: 0.1421 - accuracy: 0.9484 - val_loss: 1.1704 - val_accuracy: 0.7032 - lr: 1.0000e-05
# Epoch 50/50
# 428/428 [==============================] - 8s 18ms/step - loss: 0.1383 - accuracy: 0.9492 - val_loss: 1.1752 - val_accuracy: 0.7027 - lr: 1.0000e-05

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 286/286 [==============================] - 2s 6ms/step - loss: 1.1752 - accuracy: 0.7027
# Accuracy of our model on test data :  70.26968002319336 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 286/286 [==============================] - 1s 3ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0          disgust       disgust
# 1          disgust       disgust
# 2            angry         angry
# 3          disgust       disgust
# 4             fear          fear
# 5          disgust          fear
# 6          disgust         happy
# 7            happy         happy
# 8          disgust           sad
# 9          neutral           sad

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.83      0.80      0.82      1438
#         calm       0.80      0.87      0.83       137
#      disgust       0.58      0.70      0.63      1468
#         fear       0.72      0.60      0.66      1424
#        happy       0.69      0.70      0.69      1462
#      neutral       0.63      0.69      0.66      1310
#          sad       0.72      0.65      0.68      1400
#     surprise       0.92      0.87      0.89       483
#
#     accuracy                           0.70      9122
#    macro avg       0.74      0.73      0.73      9122
# weighted avg       0.71      0.70      0.70      9122
